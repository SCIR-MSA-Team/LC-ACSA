# %%
from pickle import load
import pickle

# %%
with open('./dataset/Restaurants_category.pkl.new', mode='rb') as in_file:
    data = pickle.load(in_file, encoding='utf-8')

# %%
len(data)
# Out:
# 6

# %%
len(data['dev'])
# Out:
# 500

# %%
for i in data["test"]:
    if len(i[2])>1:
        print(i[2])

# %%
#[tokenized_txt, actual_len, tokenized_terms, term_len, polarity, info]
data['dev'][1]
# Out:
# [[4921,
#   441,
#   2564,
#   215,
#   5158,
#   2455,
#   1950,
#   1891,
#   779,
#   1017,
#   382,
#   5194,
#   3915,
#   5080],
#  14,
#  [3024],
#  1,
#  1,
#  None]

# %%
for i in data['dev'][0][0]:
    print(data["index_word"][i])
# Out:
# stuffing
# yourself
# with
# japanese
# food
# is
# a
# rare
# thing

# %%
for i in data['dev'][0][0]:
    print(data["index_word"][i])

# %%
data.keys()
# Out:
# dict_keys(['word_index', 'dev', 'train', 'glove', 'test', 'index_word'])

# %%
len(data["index_word"])
# Out:
# 5235

# %%
data["index_word"]
# Out:
# {0: '<pad>',
#  1: '<unk>',
#  2: 'rasamalai',
#  3: 'secondly',
#  4: 'legacies',
#  5: '',
#  6: 'limited',
#  7: 'ciao',
#  8: 'hats',
#  9: 'saves',
#  10: 'dynamic',
#  11: 'monte',
#  12: 'yellow',
#  13: 'sleek',
#  14: 'four',
#  15: 'kamasutra',
#  16: 'lurking',
#  17: 'asian',
#  18: 'gras',
#  19: 'hanging',
#  20: 'famished',
#  21: 'gabriella',
#  22: 'captain',
#  23: 'hate',
#  24: 'greens',
#  25: 'forget',
#  26: 'ultrathick',
#  27: 'parisian',
#  28: 'fronts',
#  29: 'pedro',
#  30: 'tostada',
#  31: 'attracted',
#  32: 'paris',
#  33: 'butch',
#  34: '161',
#  35: '347',
#  36: 'walks',
#  37: 'whatsoever',
#  38: 'under',
#  39: 'sorry',
#  40: 'pride',
#  41: 'worth',
#  42: 'adventure',
#  43: 'smoothies',
#  44: 'chennai',
#  45: 'louder',
#  46: 'deli',
#  47: 'seasonally',
#  48: 'definetly',
#  49: 'every',
#  50: 'figs',
#  51: 'messy',
#  52: 'devine',
#  53: 'bringing',
#  54: 'encounter',
#  55: 'tickets',
#  56: 'sichuan',
#  57: 'wary',
# ...

# %%
data["word_index"]
# Out:
# {'rasamalai': 2,
#  'secondly': 3,
#  'legacies': 4,
#  '': 5,
#  'limited': 6,
#  'ciao': 7,
#  'hats': 8,
#  'saves': 9,
#  'dynamic': 10,
#  'monte': 11,
#  'yellow': 12,
#  'sleek': 13,
#  'four': 14,
#  'catch': 883,
#  'asian': 17,
#  'hanging': 19,
#  'appetite': 93,
#  'captain': 22,
#  'hate': 23,
#  'worked': 884,
#  'doughy': 4621,
#  'poorly': 113,
#  'stinks': 118,
#  'whose': 1519,
#  'fronts': 28,
#  'pedro': 29,
#  'tostada': 30,
#  'attracted': 31,
#  'paris': 32,
#  '161': 34,
#  '347': 35,
#  'whatsoever': 37,
#  'under': 38,
#  'fromager': 4324,
#  'sorry': 39,
#  'pride': 40,
#  'worth': 41,
#  'chennai': 44,
#  'phrase': 2898,
#  'deli': 46,
#  'regional': 2112,
#  'every': 49,
#  'figs': 50,
#  'jealous': 4223,
#  'devine': 52,
#  'bringing': 53,
#  'encounter': 54,
#  'tickets': 55,
#  'sichuan': 56,
#  'school': 370,
#  'prize': 58,
#  'strayed': 59,
#  'wooden': 60,
#  'clientele': 61,
#  'wednesday': 62,
#  'waldy': 63,
#  'frozen': 64,
# ...

# %%
len(data['train'])
# Out:
# 3018

# %%
print(data['glove'])
# Out:
# None

# %%
len(data['index_word'])
# Out:
# 5235

# %%
len(data['test'])
# Out:
# 973

# %%
657+222+94
# Out:
# 973
